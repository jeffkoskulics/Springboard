# %% [markdown]
# # Visualizing kmeans clusters with bivariate distribution plots

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/step3_output.csv')
df.drop(df.columns[[0,1,2,3,]],axis=1,inplace=True)
X = df.drop(['kmeans'],axis=1)
Y = df['kmeans']

z = pd.plotting.scatter_matrix(X, c=Y, alpha=.25, figsize=(20,20))
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
frame1.axes.yaxis.set_ticklabels([])
plt.show()

# %%
df = pd.read_csv('../data/step3scaled.csv')
df.drop(df.columns[[0,1,2,3,]],axis=1,inplace=True)
X = df.drop(['kmeans'],axis=1)
Y = df['kmeans']

z = pd.plotting.scatter_matrix(X, c=Y, alpha=.25, figsize=(20,20))
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
frame1.axes.yaxis.set_ticklabels([])
plt.show()
