# %% [markdown]
# # Detecting Disaster Tweets
# In this project, we will examine a dataset of Tweets to identify which Tweets are about a real disaster. The dataset is hosted on Kaggle as an introduction to Natural Language Processing:
#
# ### Real or Not? NLP with Disaster Tweets
# #### Predict which Tweets are about real disasters and which ones are not
# https://www.kaggle.com/c/nlp-getting-started
#
# The data are downloaded and stored in this project folder in the `../downloads` directory. As a first step, let's examine the dataset:

# %%
import pandas as pd

train = pd.read_csv('../downloads/train.csv')
test = pd.read_csv('../downloads/test.csv')
sample_submission = pd.read_csv('../downloads/sample_submission.csv')

# %% [markdown]
# ## Text cleaning
# After some analysis (not shown here), a few things were discovered:
#
# - NaN values in keyword and locations
# - the text is stored as "escaped html" that appears as strange codes within text
# - there are some unicode character errors
# - the text contains URLs
# - lots of spelling errors!
#
# Let's clean them up...

# %%
train.keyword.fillna('',inplace=True)
test.keyword.fillna('',inplace=True)
train.location.fillna('',inplace=True)
test.location.fillna('',inplace=True)

import html, re

def clean_text(text):
    text = html.unescape(text) #clean up html escape codes
    text = str(text.encode('ascii','ignore'),'utf8') #clean unicode errors
    text = re.sub('http\S+','',text) #delete URLs
    text = re.sub('\%20','_',text) #delete unescaped spaces in keywords
    text = re.sub('\n',' ',text) #delete newlines from tweets
    text = re.sub('#\S+','',text) #delete hashtags
    text = re.sub('@\S+','',text)
    return text
    
train['text'] = train['text'].apply(clean_text)
train['keyword'] = train['keyword'].apply(clean_text)
train['location'] = train['location'].apply(clean_text)

test['text'] = test['text'].apply(clean_text)
test['keyword'] = test['keyword'].apply(clean_text)
test['location'] = test['location'].apply(clean_text)

# %%
train.sample(5, random_state = 1)
# Out:
#          id             keyword                  location  \
# 3228   4632  emergency_services   Sydney, New South Wales
# 3706   5271                fear
# 6957   9982             tsunami         Land Of The Kings
# 2887   4149               drown
# 7464  10680              wounds  cody, austin follows ?*?
#
#                                                    text  target
# 3228  Goulburn man Henry Van Bilsen missing: Emergen...       1
# 3706  The things we fear most in organizations--fluc...       0
# 6957                                         ?? hey Esh       0
# 2887   you until you drown by water entering the lun...       0
# 7464  Crawling in my skin These wounds they will not...       1

# %%
test.sample(5, random_state = 1)
# Out:
#         id       keyword                  location  \
# 1787  6035     heat_wave              Brooklyn, NY
# 666   2168  catastrophic
# 93     317   annihilated
# 2924  9682       tornado                    Canada
# 1735  5857     hailstorm  Calgary, Alberta, Canada
#
#                                                    text
# 1787  I added some dumb ideas to beat the  heat chea...
# 666   If a 1 rise in wages is going to have such a c...
# 93    How do I step outside for 5 seconds and get an...
# 2924      Tornado warnings issued for southern Alberta
# 1735  Get out of the hailstorm and come down to  2ni...

# %%
sample_submission.sample(5, random_state = 1)
# Out:
#         id  target
# 1787  6035       0
# 666   2168       0
# 93     317       0
# 2924  9682       0
# 1735  5857       0

# %% [markdown]
# The train.csv file contains a table with the following columns:
# - id
# - keyword
# - location
# - text
# - target
#
# The test.csv file contains the same columns as train but the target values are missing. Our objective will be to predict these values. The sample_submission.csv file contains only the id and target values. To perform in the Kaggle competition, we will submit a csv file with a table of id and target values to see how our model compares with other competitors.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Let's ask a few questions that we can answer by exploring the data:
#
# - Do the test.csv and sample_submission.csv files have identical id values?
# - How large are the test and train sets?
# - How many unique keywords are there?
# - Are there any keywords not common among train and test sets?
# - How many locations are there?
# - Are there any locations not common among train and test sets?
# - Are there any duplicated values in either set?
# - How is the train target distributed?

# %%
# Do the test.csv and sample_submission.csv files have identical id values?

import numpy as np

assert np.all(test.id == sample_submission.id)

# %%
# How large are the test and train sets? 

print('Train size:', len(train.index))
print('Test size: ', len(test.index))
# Out:
# Train size: 7613
# Test size:  3263

# %%
# How many unique keywords are there?
print('Number of train set keywords:', train.keyword.nunique())
print('Number of test set keywords: ', test.keyword.nunique())
# Out:
# Number of train set keywords: 222
# Number of test set keywords:  222

# %%
# Are there any keywords not common among train and test sets?

train_keywords = set(train.keyword)
test_keywords = set(test.keyword)
print('Number of keywords not common to both sets:', len(test_keywords - train_keywords))
# Out:
# Number of keywords not common to both sets: 0

# %%
# How many unique locations are there?

print('Number of train set locations:', train.location.nunique())
print('Number of test set locations: ', test.location.nunique())
# Out:
# Number of train set locations: 3313
# Number of test set locations:  1584

# %%
# Are there any locations not common among train and test sets?

train_locations = set(train.location)
test_locations = set(test.location)
print('Number of locations not common to both sets:', len(test_locations.symmetric_difference(train_locations)))
print('Number of locations common to both sets:', len(test_locations.intersection(train_locations)))
# Out:
# Number of locations not common to both sets: 4053
# Number of locations common to both sets: 422

# %%
# Are there any duplicated values in either set?

train_duplicates = train.duplicated(subset=['text'],keep=False)
test_duplicates = test.duplicated(subset=['text'],keep=False)

print('Duplicated train items:' ,np.sum(train_duplicates))
print('Duplicated test items: ' ,np.sum(test_duplicates))
# Out:
# Duplicated train items: 983
# Duplicated test items:  261

# %%
# How is the train target distributed?

import matplotlib.pyplot as plt

train.target.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Duplicates
# Both the test and training sets have duplicated values. Let's explore these a bit more:

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None
pd.options.display.width = 1000
train[train_duplicates].sort_values(['text','location'])
# Out:
#          id             keyword                                location                                               text  target
# 2165   3106              debris                                              MH370: Aircraft debris found on La Reunion...       1
# 2168   3109              debris                                              MH370: Aircraft debris found on La Reunion...       1
# 2170   3112              debris                                              MH370: Aircraft debris found on La Reunion...       1
# 2175   3118              debris                                              MH370: Aircraft debris found on La Reunion...       1
# 2182   3126              debris                                              MH370: Aircraft debris found on La Reunion...       1
# 6413   9171      suicide_bomber                                              Suicide bomber kills 15 in Saudi security ...       1
# 6416   9174      suicide_bomber                                              Suicide bomber kills 15 in Saudi security ...       1
# 6426   9191      suicide_bomber                                              Suicide bomber kills 15 in Saudi security ...       1
# 4221   5996           hazardous                                             slips into loss after   unsafe and hazardou...       1
# 4239   6023           hazardous                       Mysore, Karnataka     slips into loss after   unsafe and hazardou...       1
# 4244   6031           hazardous                        New Delhi, Delhi     slips into loss after   unsafe and hazardou...       0
# 2822   4057           displaced                                            12News: UPDATE: A family of 3 has been displ...       1
# 2828   4064           displaced                                            12News: UPDATE: A family of 3 has been displ...       1
# 7134  10218             volcano                                            Asics GT-II Super Red 2.0 11 Ronnie Fieg Kit...       0
# 7141  10231             volcano                         California, USA    Asics GT-II Super Red 2.0 11 Ronnie Fieg Kit...       0
# 6951   9973             tsunami                                            Beginners  tutorial.:  Everyone Wants To Lea...       0
# 6956   9980             tsunami                                            Beginners  tutorial.:  Everyone Wants To Lea...       0
# 4462   6345            hostages                                            C-130 specially modified to land in a stadiu...       1
# 4485   6380            hostages                            EastCarolina    C-130 specially modified to land in a stadiu...       1
# 4453   6336            hostages                                   Japan    C-130 specially modified to land in a stadiu...       1
# 4454   6337            hostages                           Las Vegas, NV    C-130 specially modified to land in a stadiu...       1
# 4461   6344            hostages                               Tennessee    C-130 specially modified to land in a stadiu...       1
# 4476   6366            hostages                                   china    C-130 specially modified to land in a stadiu...       0
# 4486   6382            hostages                                   china    C-130 specially modified to land in a stadiu...       1
# 4475   6365            hostages                                    cuba    C-130 specially modified to land in a stadiu...       1
# 2027   2910              danger                               Worldwide    Check out this  preview of  Danger Zone Comi...       0
# 2029   2912              danger                               Worldwide    Check out this  preview of  Danger Zone Comi...       0
# 2043   2933              danger                               Worldwide    Check out this  preview of  Danger Zone Comi...       0
# 5807   8288             rioting                                 Alabama                                Cindy Noonan in           0
# 5785   8254             rioting                               Vista, CA                                Cindy Noonan in           1
# 2816   4049           displaced                Pedophile hunting ground    Displaced  at  point of no return    like co...       1
# 2841   4086           displaced                Pedophile hunting ground    Displaced  at  point of no return    like co...       1
# 4403   6259           hijacking                                            Funtenna: hijacking computers to send data a...       1
# 4405   6262           hijacking                                            Funtenna: hijacking computers to send data a...       0
# 4414   6274           hijacking                                            Funtenna: hijacking computers to send data a...       1
# 4420   6283           hijacking                                            Funtenna: hijacking computers to send data a...       1
# 4400   6256           hijacking                                  Brazil    Funtenna: hijacking computers to send data a...       0
# 4412   6272           hijacking                                  Brazil    Funtenna: hijacking computers to send data a...       0
# 4394   6246           hijacking                                   China    Funtenna: hijacking computers to send data a...       0
# 4396   6248           hijacking                     Chiyoda Ward, Tokyo    Funtenna: hijacking computers to send data a...       0
# 4399   6255           hijacking                            EastCarolina    Funtenna: hijacking computers to send data a...       0
# 4404   6261           hijacking                                  France    Funtenna: hijacking computers to send data a...       0
# 4415   6276           hijacking                                   Japan    Funtenna: hijacking computers to send data a...       1
# 4392   6244           hijacking                                Mongolia    Funtenna: hijacking computers to send data a...       1
# 4393   6245           hijacking                     brisbane, australia    Funtenna: hijacking computers to send data a...       0
# 4408   6267           hijacking                                   china    Funtenna: hijacking computers to send data a...       0
# 4391   6243           hijacking                       perth, australia     Funtenna: hijacking computers to send data a...       0
# 4397   6253           hijacking                                    rome    Funtenna: hijacking computers to send data a...       0
# 4407   6265           hijacking                                   tokyo    Funtenna: hijacking computers to send data a...       0
# 1201   1727   buildings_burning                             Madison, GA      I must be overlooking the burning buildings?        1
# 1356   1957   burning_buildings                             Madison, GA      I must be overlooking the burning buildings?        1
# 2035   2921              danger                        Atlanta Georgia     IS  OPPRESSIONS GREATEST DANGER COMING SOON ...       0
# 2040   2929              danger                        Atlanta Georgia     IS  OPPRESSIONS GREATEST DANGER COMING SOON ...       1
# 2045   2935              danger                        Atlanta Georgia     IS  OPPRESSIONS GREATEST DANGER COMING SOON ...       0
# 2046   2936              danger                        Atlanta Georgia     IS  OPPRESSIONS GREATEST DANGER COMING SOON ...       0
# 4222   5997           hazardous                                            Olap  pres:  How To Recognize A Hazardous Wa...       0
# 4245   6032           hazardous                                            Olap  pres:  How To Recognize A Hazardous Wa...       1
# 4878   6946            massacre                                            Parents of Colorado theater shooting victim ...       1
# 4881   6950            massacre                                            Parents of Colorado theater shooting victim ...       1
# 4908   6985            massacre                                            Parents of Colorado theater shooting victim ...       1
# 4909   6988            massacre                                            Parents of Colorado theater shooting victim ...       1
# 5534   7894         quarantined                                   China    Reddit's new content policy goes into effect...       0
# 5509   7862         quarantined                               Melbourne    Reddit's new content policy goes into effect...       1
# 5526   7882         quarantined                                Mongolia    Reddit's new content policy goes into effect...       0
# 5502   7851         quarantined                            South Africa    Reddit's new content policy goes into effect...       0
# 5504   7854         quarantined                                  russia    Reddit's new content policy goes into effect...       0
# 7315  10470          wild_fires                                            The out of control wild fires in California ...       1
# 7609  10870                                                                The out of control wild fires in California ...       1
# 1481   2134         catastrophe                                            Ultimate  library:  Prepare Yourself For Any...       0
# 1487   2144         catastrophe                                            Ultimate  library:  Prepare Yourself For Any...       1
# 4827   6874         mass_murder                               Anonymous    do your passengers know about the mass murde...       1
# 4834   6881         mass_murder                               Anonymous    do your passengers know about the mass murde...       1
# 6363   9095        suicide_bomb                                 Nigeria   16yr old PKK suicide bomber who detonated bom...       1
# 6366   9098        suicide_bomb                                 Nigeria   16yr old PKK suicide bomber who detonated bom...       1
# 6373   9107        suicide_bomb                                 Nigeria   16yr old PKK suicide bomber who detonated bom...       1
# 6377   9113        suicide_bomb                                 Nigeria   16yr old PKK suicide bomber who detonated bom...       1
# 6378   9114        suicide_bomb                                 Nigeria   16yr old PKK suicide bomber who detonated bom...       1
# 6392   9135        suicide_bomb                                 Nigeria   16yr old PKK suicide bomber who detonated bom...       1
# 2125   3053              deaths                                           2 deaths from measles complications in 10 yrs...       1
# 2134   3062              deaths                                           2 deaths from measles complications in 10 yrs...       1
# 1704   2459            collided                        Peterborough, On   2 vehicles collided at Lock and Lansdowne Sts...       1
# 1725   2488            collided                      Peterborough, Ont.   2 vehicles collided at Lock and Lansdowne Sts...       1
# 5837   8341              rubble                      ATLANTA , GEORGIA    : China's Stock Market Crash: Are There Gems ...       0
# 5817   8301              rubble                             Accra,Ghana   : China's Stock Market Crash: Are There Gems ...       0
# 5823   8314              rubble                                  London   : China's Stock Market Crash: Are There Gems ...       1
# 5833   8334              rubble                   Made Here In Detroit    : China's Stock Market Crash: Are There Gems ...       1
# 2646   3798            detonate                           Morioh, Japan   Are you another Stand-user? If you are I will...       0
# 2651   3806            detonate                           Morioh, Japan   Are you another Stand-user? If you are I will...       0
# 2655   3814            detonate                           Morioh, Japan   Are you another Stand-user? If you are I will...       0
# 2666   3828            detonate                           Morioh, Japan   Are you another Stand-user? If you are I will...       0
# 2674   3836            detonate                           Morioh, Japan   Are you another Stand-user? If you are I will...       0
# 2679   3841            detonate                           Morioh, Japan   Are you another Stand-user? If you are I will...       0
# 5813   8296              rubble                                           Chinas stock market crash this summer has spa...       1
# 5814   8297              rubble                                           Chinas stock market crash this summer has spa...       0
# 4499   6396           hurricane                        Berlin - Germany                               Did you see   with         1
# 4514   6415           hurricane                        Berlin - Germany                               Did you see   with         1
# 5744   8202                riot                                                     Discovered by    Listen/Buy   on    _        0
# 5754   8214                riot                                                     Discovered by    Listen/Buy   on    _        0
# 5773   8240                riot                                                     Discovered by    Listen/Buy   on    _        0
# 4918   7005              mayhem                           BOSTON-LONDON       Editor In Chief  Releases Issue   of    and        0
# 4930   7024              mayhem                        Boston/Montreal        Editor In Chief  Releases Issue   of    and        0
# 4920   7008              mayhem                        GLOBAL/WORLDWIDE       Editor In Chief  Releases Issue   of    and        0
# 4938   7036              mayhem                        WORLDWIDE-BOSTON       Editor In Chief  Releases Issue   of    and        0
# 591     853           bioterror                                           FedEx no longer to transport bioterror germs ...       0
# 587     848           bioterror                                  iTunes   FedEx no longer to transport bioterror germs ...       1
# 4981   7106            military                                           For the people who died in Human Experiments ...       1
# 4990   7120            military                                           For the people who died in Human Experiments ...       1
# 4993   7124            military                                           For the people who died in Human Experiments ...       1
# 5002   7135            military                                           For the people who died in Human Experiments ...       1
# 5004   7137            military                                           For the people who died in Human Experiments ...       1
# 2366   3403              derail           Road to the Billionaires Club   GM! I pray any attack of the enemy 2 derail u...       0
# 2369   3406              derail           Road to the Billionaires Club   GM! I pray any attack of the enemy 2 derail u...       0
# 2375   3414              derail           Road to the Billionaires Club   GM! I pray any attack of the enemy 2 derail u...       1
# 2380   3421              derail           Road to the Billionaires Club   GM! I pray any attack of the enemy 2 derail u...       0
# 2382   3425              derail           Road to the Billionaires Club   GM! I pray any attack of the enemy 2 derail u...       0
# 2394   3445              derail           Road to the Billionaires Club   GM! I pray any attack of the enemy 2 derail u...       0
# 5973   8528           screaming                                                                               IM SCREAMING       1
# 5961   8512           screaming                        [ is my frankie]                                       IM SCREAMING       0
# 614     885        bioterrorism                                           If 90BLKs&8WHTs colluded 2 take WHT F  AUTH H...       1
# 633     915        bioterrorism                                           If 90BLKs&8WHTs colluded 2 take WHT F  AUTH H...       1
# 635     919        bioterrorism                                           If 90BLKs&8WHTs colluded 2 take WHT F  AUTH H...       1
# 2925   4204             drowned                             Alberta, VA   Jacksonville family bands together as memoria...       0
# 2934   4216             drowned                        Colorado Springs   Jacksonville family bands together as memoria...       0
# 4726   6722                lava                                 Jakarta                          Lava Blast & Power Red          0
# 4716   6706                lava                         Medan,Indonesia                          Lava Blast & Power Red          0
# 4143   5890                harm                             Kansas City   Love what you picked! We're playing WORTH IT ...       1
# 4149   5898                harm                             Kansas City   Love what you picked! We're playing WORTH IT ...       0
# 4168   5921                harm                             Kansas City   Love what you picked! We're playing WORTH IT ...       0
# 3795   5387          fire_truck                       Orange County, CA   North & Southbound 133 closed btwn 5 fwy and ...       1
# 3790   5382          fire_truck                   Orange County, Calif.   North & Southbound 133 closed btwn 5 fwy and ...       1
# 7514  10747            wreckage                                           Now that a piece of wreckage from flight MH37...       1
# 7527  10765            wreckage                                  iTunes   Now that a piece of wreckage from flight MH37...       1
# 7532  10770            wreckage                                  iTunes   Now that a piece of wreckage from flight MH37...       1
# 395     570               arson                          Eldoret, kenya   Police in Kisii hunt for students over failed...       1
# 402     579               arson                          Eldoret, kenya   Police in Kisii hunt for students over failed...       1
# 4925   7015              mayhem                      107-18 79TH STREET   Results: Full Metal Mayhem World Title Match ...       0
# 4942   7044              mayhem                      107-18 79TH STREET   Results: Full Metal Mayhem World Title Match ...       0
# 5952   8503           screaming                                                                                  SCREAMING       0
# 5962   8513           screaming                      Daddy Kink Central                                          SCREAMING       0
# 6740   9657        thunderstorm                                           Severe Weather Statement issued August 05 at ...       1
# 6714   9616        thunderstorm                                 Jupiter   Severe Weather Statement issued August 05 at ...       1
# 2493   3582            desolate                            Macclesfield   TY for the follow Go To  BRUTALLY ABUSED+DESO...       1
# 2499   3589            desolate                            Macclesfield   TY for the follow Go To  BRUTALLY ABUSED+DESO...       0
# 1242   1790   buildings_on_fire                               Scotland                     Those two buildings are on fire       1
# 1251   1807   buildings_on_fire                                      UK                    Those two buildings are on fire       1
# 190     269           ambulance                                           Twelve feared killed in Pakistani air ambulan...       1
# 196     276           ambulance                                           Twelve feared killed in Pakistani air ambulan...       1
# 202     285           ambulance                                           Twelve feared killed in Pakistani air ambulan...       1
# 183     262           ambulance                               Amsterdam   Twelve feared killed in Pakistani air ambulan...       1
# 172     247           ambulance                                 Jackson   Twelve feared killed in Pakistani air ambulan...       1
# 197     277           ambulance                                   L. A.   Twelve feared killed in Pakistani air ambulan...       1
# 201     283           ambulance                               Lexington   Twelve feared killed in Pakistani air ambulan...       1
# 207     293           ambulance                                   Playa   Twelve feared killed in Pakistani air ambulan...       1
# 7097  10169       violent_storm                                           Violent Record Breaking EF-5 El Reno Oklahoma...       1
# 7607  10867                                                               Violent Record Breaking EF-5 El Reno Oklahoma...       1
# 257     365        annihilation                                           We need help! Horses will die!Please RT & sig...       1
# 262     375        annihilation                                           We need help! Horses will die!Please RT & sig...       0
# 1202   1728   buildings_burning                                           all lives matter. Just not a fan of burning d...       1
# 1335   1929   burning_buildings                                           all lives matter. Just not a fan of burning d...       1
# 4299   6105            hellfire              ?????? ??? ?????? ????????   describes piling up  thinking it would last  ...       0
# 4312   6123            hellfire                      ?????? ???? ??????   describes piling up  thinking it would last  ...       1
# 4290   6094            hellfire                Jubail IC, Saudi Arabia.   describes piling up  thinking it would last  ...       0
# 1199   1725   buildings_burning                                      NJ   not upset with a rally upset with burning bui...       1
# 1343   1941   burning_buildings                                      NJ   not upset with a rally upset with burning bui...       1
# 4552   6470             injured                                Bronx NY   please support this Please cosponsor S. 928 a...       1
# 4559   6481             injured                                Bronx NY   please support this Please cosponsor S. 928 a...       1
# 3163   4541           emergency                       Renfrew, Scotland   we enjoyed the show today. Great fun. The eme...       0
# 3382   4844          evacuation                       Renfrew, Scotland   we enjoyed the show today. Great fun. The eme...       0
# 5246   7502           oil_spill                                Amarillo  'California: Spring Oil Spill Estimate Grows '...       1
# 5279   7544           oil_spill                          Corpus Christi  'California: Spring Oil Spill Estimate Grows '...       1
# 3551   5075              famine                                          'Food crematoria' provoke outrage amid crisis ...       1
# 3541   5063              famine                           New York, USA  'Food crematoria' provoke outrage amid crisis ...       1
# 6434   9207     suicide_bombing                                                 'Suicide bombing at [location named]...'         1
# 6449   9225     suicide_bombing                                                 'Suicide bombing at [location named]...'         1
# 2719   3905          devastated                    REPUBLICA DOMINICANA  ( Obama Declares Disaster for Typhoon-Devastat...       1
# 7034  10080             typhoon                    REPUBLICA DOMINICANA  ( Obama Declares Disaster for Typhoon-Devastat...       1
# 3839   5462              flames                                New York  *NEW* Snap On Tools Black baseball Hat/Cap Sil...       0
# 3840   5465              flames                                New York  *NEW* Snap On Tools Black baseball Hat/Cap Sil...       0
# 3852   5481              flames                                New York  *NEW* Snap On Tools Black baseball Hat/Cap Sil...       0
# 5622   8020            refugees                                          ...//..// whao.. 12000 Nigerian refugees repat...       1
# 5634   8035            refugees                                          ...//..// whao.. 12000 Nigerian refugees repat...       1
# 5646   8056            refugees                                          ...//..// whao.. 12000 Nigerian refugees repat...       1
# 5621   8019            refugees                                          ./.....hmm 12000 Nigerian refugees repatriated...       1
# 5635   8036            refugees                                          ./.....hmm 12000 Nigerian refugees repatriated...       1
# 2830   4068           displaced                Pedophile hunting ground  .POTUS  is a strategy for  refugees; IDP Inter...       1
# 2831   4072           displaced                Pedophile hunting ground  .POTUS  is a strategy for  refugees; IDP Inter...       1
# 2832   4076           displaced                Pedophile hunting ground  .POTUS  is a strategy for  refugees; IDP Inter...       0
# 2833   4077           displaced                Pedophile hunting ground  .POTUS  is a strategy for  refugees; IDP Inter...       1
# 2818   4051           displaced                                    U.S.  .POTUS  is a strategy for  refugees; IDP Inter...       1
# 6376   9112        suicide_bomb                                          //./../.. Pic of 16yr old PKK suicide bomber w...       1
# 6379   9116        suicide_bomb                                          //./../.. Pic of 16yr old PKK suicide bomber w...       1
# 4326   6145              hijack                                          0-day bug in fully patched OS X comes under ac...       0
# 4339   6163              hijack                                          0-day bug in fully patched OS X comes under ac...       0
# 3907   5557           flattened                                          100  1' MIX NEW FLAT DOUBLE SIDED LINERLESS BO...       0
# 3910   5560           flattened                                New York  100  1' MIX NEW FLAT DOUBLE SIDED LINERLESS BO...       0
# 3578   5113               fatal                                          11-Year-Old Boy Charged With Manslaughter of T...       1
# 3597   5137               fatal                                          11-Year-Old Boy Charged With Manslaughter of T...       1
# 3600   5140               fatal                                          11-Year-Old Boy Charged With Manslaughter of T...       1
# 3603   5144               fatal                                          11-Year-Old Boy Charged With Manslaughter of T...       1
# 3613   5157               fatal                                          11-Year-Old Boy Charged With Manslaughter of T...       1
# 3614   5159               fatal                                          11-Year-Old Boy Charged With Manslaughter of T...       1
# 3604   5145               fatal                               Bangalore  11-Year-Old Boy Charged With Manslaughter of T...       1
# 3610   5153               fatal                                 Dimapur  11-Year-Old Boy Charged With Manslaughter of T...       1
# 3591   5130               fatal                                   Thane  11-Year-Old Boy Charged With Manslaughter of T...       1
# 3589   5127               fatal                                Varanasi  11-Year-Old Boy Charged With Manslaughter of T...       1
# 3923   5579               flood                                New York  12' 72W CREE LED Work Light Bar Alloy Spot Flo...       0
# 3945   5609               flood                                New York  12' 72W CREE LED Work Light Bar Alloy Spot Flo...       0
# 4991   7121            military                                          13 reasons why we love women in the military  ...       0
# 5001   7134            military                                     302  13 reasons why we love women in the military  ...       0
# 4997   7129            military                               Boston MA  13 reasons why we love women in the military  ...       0
# 5000   7132            military                                      NY  13 reasons why we love women in the military  ...       0
# 1719   2480            collided                                          16 dead in Russia bus accident: At least 16 pe...       1
# 1733   2497            collided                                  Mumbai  16 dead in Russia bus accident: At least 16 pe...       1
# 6383   9121        suicide_bomb                                          16yr old PKK suicide bomber who detonated bomb...       1
# 6384   9123        suicide_bomb              Did anybody see me here ??  16yr old PKK suicide bomber who detonated bomb...       1
# 6390   9132        suicide_bomb                                  GLOBAL  16yr old PKK suicide bomber who detonated bomb...       1
# 6382   9120        suicide_bomb                           lagos. Unilag  16yr old PKK suicide bomber who detonated bomb...       1
# 2376   3415              derail                           Nairobi-KENYA  24 killed in two simultaneous rail crash as ac...       1
# 2391   3437              derail                           Nairobi-KENYA  24 killed in two simultaneous rail crash as ac...       1
# 3917   5570               flood                                          2pcs 18W CREE Led Work Light  Offroad Lamp Car...       0
# 3924   5580               flood                                New York  2pcs 18W CREE Led Work Light  Offroad Lamp Car...       1
# 3930   5588               flood                                New York  2pcs 18W CREE Led Work Light  Offroad Lamp Car...       0
# 3933   5592               flood                                New York  2pcs 18W CREE Led Work Light  Offroad Lamp Car...       0
# 5093   7265    nuclear_disaster                                          3 former executives to be prosecuted in Fukush...       1
# 5091   7261    nuclear_disaster                   Inexpressible Island   3 former executives to be prosecuted in Fukush...       1
# 116     168          aftershock                                               320 [IR] ICEMOON [AFTERSHOCK] |  |  |              0
# 104     151          aftershock                             Switzerland       320 [IR] ICEMOON [AFTERSHOCK] |  |  |              0
# 114     164          aftershock                             Switzerland       320 [IR] ICEMOON [AFTERSHOCK] |  |  |              0
# 118     171          aftershock                             Switzerland       320 [IR] ICEMOON [AFTERSHOCK] |  |  |              0
# 119     172          aftershock                             Switzerland       320 [IR] ICEMOON [AFTERSHOCK] |  |  |              0
# 106     156          aftershock                                      US       320 [IR] ICEMOON [AFTERSHOCK] |  |  |              0
# 115     165          aftershock                                      US       320 [IR] ICEMOON [AFTERSHOCK] |  |  |              0
# 2753   3956         devastation                                          70 Years After Atomic Bombs Japan Still Strugg...       1
# 2770   3982         devastation                                          70 Years After Atomic Bombs Japan Still Strugg...       1
# 2771   3983         devastation                                          70 Years After Atomic Bombs Japan Still Strugg...       1
# 2775   3992         devastation                                          70 Years After Atomic Bombs Japan Still Strugg...       1
# 2752   3955         devastation                                    News  70 Years After Atomic Bombs Japan Still Strugg...       1
# 2757   3960         devastation                           United States  70 Years After Atomic Bombs Japan Still Strugg...       1
# 2762   3968         devastation               Upper manhattan, New York  70 Years After Atomic Bombs Japan Still Strugg...       1
# 2749   3952         devastation                           Wasington, DC  70 Years After Atomic Bombs Japan Still Strugg...       1
# 2759   3962         devastation                       contactSimpleNews  70 Years After Atomic Bombs Japan Still Strugg...       1
# 969    1402            body_bag                                Paignton  ?? New Ladies Shoulder Tote  Faux Leather Hobo...       0
# 974    1409            body_bag                                Paignton  ?? New Ladies Shoulder Tote  Faux Leather Hobo...       1
# 981    1420            body_bag                                Paignton  ?? New Ladies Shoulder Tote  Faux Leather Hobo...       0
# 7048  10099             typhoon                                            A GPM satellite 'bullseye' in Typhoon Soudelor        1
# 7045  10092             typhoon                                   india    A GPM satellite 'bullseye' in Typhoon Soudelor        1
# 4633   6585           inundated                                 Ireland  A Laois girl advertised for a new friend to re...       0
# 4639   6596           inundated                                 Ireland  A Laois girl advertised for a new friend to re...       0
# 1193   1719     bridge_collapse                                          A Marshall Plan for the United States by Dambi...       0
# 1160   1671     bridge_collapse                            Vit_ria (ES)  A Marshall Plan for the United States by Dambi...       0
# 7091  10156            upheaval                             Connecticut  A look at state actions a year after Ferguson'...       1
# 7056  10110            upheaval                                  Oregon  A look at state actions a year after Ferguson'...       0
# 7068  10124            upheaval                                  Oregon  A look at state actions a year after Ferguson'...       0
# 178     254           ambulance            Happily Married with 2 kids   AMBULANCE SPRINTER AUTOMATIC FRONTLINE VEHICLE...       0
# 186     265           ambulance            Happily Married with 2 kids   AMBULANCE SPRINTER AUTOMATIC FRONTLINE VEHICLE...       0
# 192     271           ambulance            Happily Married with 2 kids   AMBULANCE SPRINTER AUTOMATIC FRONTLINE VEHICLE...       0
# 193     272           ambulance            Happily Married with 2 kids   AMBULANCE SPRINTER AUTOMATIC FRONTLINE VEHICLE...       0
# 131     190          aftershock                                                                                Aftershock        0
# 113     163          aftershock                                 Belgium                                        Aftershock        0
# 7077  10138            upheaval                                          Ancient Mayan Tablet with Hieroglyphics Honors...       0
# 7076  10137            upheaval                                 Woosley  Ancient Mayan Tablet with Hieroglyphics Honors...       0
# 2836   4080           displaced                                 Nigeria  Angry Woman Openly Accuses NEMA Of Stealing Re...       1
# 2846   4092           displaced                                 Nigeria  Angry Woman Openly Accuses NEMA Of Stealing Re...       0
# 2823   4058           displaced                             Ojodu,Lagos  Angry Woman Openly Accuses NEMA Of Stealing Re...       0
# 1747   2514           collision                                  NY, NY                            Anti Collision Rear-          0
# 1759   2531           collision                                USA , AZ                            Anti Collision Rear-          0
# 1776   2550           collision                                 USA, WA                            Anti Collision Rear-          0
# 6465   9249                sunk                                New York  Aquarium Ornament Wreck Sailing Boat Sunk Ship...       1
# 6488   9276                sunk                                New York  Aquarium Ornament Wreck Sailing Boat Sunk Ship...       1
# 411     594               arson                                          Arson suspect linked to 30 fires caught in Nor...       1
# 417     606            arsonist                             Bleak House  Arson suspect linked to 30 fires caught in Nor...       1
# 391     565               arson                       Republic of Texas  Arson suspect linked to 30 fires caught in Nor...       1
# 1186   1707     bridge_collapse                                          Ashes 2015: Australias collapse at Trent Bridg...       0
# 1164   1676     bridge_collapse                        New Delhi, Delhi  Ashes 2015: Australias collapse at Trent Bridg...       1
# 1957   2819             cyclone                                          BBC Forced To Retract False Claims About Cyclo...       1
# 1967   2831             cyclone                                Cornwall  BBC Forced To Retract False Claims About Cyclo...       1
# 2373   3412              derail                                          BBC News - India rail crash: Trains derail in ...       1
# 2386   3431              derail                                          BBC News - India rail crash: Trains derail in ...       1
# 2377   3417              derail                              at my home  BBC News - India rail crash: Trains derail in ...       1
# 7193  10305              weapon                         Central Florida  BREAKING: Obama Officials GAVE Muslim Terroris...       1
# 459     662              attack                              Seattle WA  BREAKING: Obama Officials GAVE Muslim Terroris...       1
# 4323   6138              hijack                                          Bayelsa poll: Tension in Bayelsa as Patience J...       1
# 4348   6174              hijack                           am everywhere  Bayelsa poll: Tension in Bayelsa as Patience J...       0
# 4291   6096            hellfire                                          Beware of your temper and a loose tongue! Thes...       0
# 4303   6110            hellfire                                          Beware of your temper and a loose tongue! Thes...       0
# 4288   6092            hellfire                       jeddah | Khartoum  Beware of your temper and a loose tongue! Thes...       0
# 4521   6423           hurricane                                          Bluedio Turbine Hurricane H Bluetooth 4.1 Wire...       0
# 4498   6395           hurricane                                New York  Bluedio Turbine Hurricane H Bluetooth 4.1 Wire...       0
# 4513   6414           hurricane                                New York  Bluedio Turbine Hurricane H Bluetooth 4.1 Wire...       0
# 1222   1761   buildings_burning                  New Orleans ,Louisiana                 Burning buildings? Media outrage?        1
# 1345   1943   burning_buildings                  New Orleans ,Louisiana                 Burning buildings? Media outrage?        1
# 4597   6537              injury                                          CLEARED:incident with injury:I-495  inner loop...       1
# 4605   6548              injury                                          CLEARED:incident with injury:I-495  inner loop...       1
# 4618   6566              injury                                          CLEARED:incident with injury:I-495  inner loop...       0
# 2151   3086              deaths                               Blackpool  Cancers equate for around 25% of all deaths in...       1
# 2156   3093              deaths                               Blackpool  Cancers equate for around 25% of all deaths in...       1
# 4232   6012           hazardous                                          Caution: breathing may be hazardous to your he...       1
# 4235   6017           hazardous                                          Caution: breathing may be hazardous to your he...       0
# 40       59              ablaze                          Live On Webcam                              Check these out:            0
# 48       68              ablaze                          Live On Webcam                              Check these out:            0
# 4182   5939              hazard                             Alameda, CA  Choking Hazard Prompts Recall Of Kraft Cheese ...       1
# 4196   5959              hazard                          Pleasanton, CA  Choking Hazard Prompts Recall Of Kraft Cheese ...       0
# 491     712            attacked                                          Christian Attacked by Muslims at the Temple Mo...       1
# 492     713            attacked                                          Christian Attacked by Muslims at the Temple Mo...       1
# 499     724            attacked                                          Christian Attacked by Muslims at the Temple Mo...       1
# 490     710            attacked                          AKRON OHIO USA  Christian Attacked by Muslims at the Temple Mo...       1
# 508     734            attacked                                 America  Christian Attacked by Muslims at the Temple Mo...       1
# 506     731            attacked                                Arundel   Christian Attacked by Muslims at the Temple Mo...       1
# 504     729            attacked          Groningen, Netherlands, Europe  Christian Attacked by Muslims at the Temple Mo...       1
# 500     725            attacked                        LEALMAN, FLORIDA  Christian Attacked by Muslims at the Temple Mo...       1
# 505     730            attacked                  Livingston, IL  U.S.A.  Christian Attacked by Muslims at the Temple Mo...       1
# 495     717            attacked                                  London  Christian Attacked by Muslims at the Temple Mo...       1
# 516     745            attacked                            Oslo, Norway  Christian Attacked by Muslims at the Temple Mo...       1
# 514     740            attacked                    So Paulo SP,  Brasil  Christian Attacked by Muslims at the Temple Mo...       1
# 512     738            attacked                    The Hammock, FL, USA  Christian Attacked by Muslims at the Temple Mo...       1
# 510     736            attacked                                     USA  Christian Attacked by Muslims at the Temple Mo...       1
# 511     737            attacked                                  israel  Christian Attacked by Muslims at the Temple Mo...       1
# 5651   8062              rescue                                          Coastal German Shepherd Rescue OC shared a lin...       0
# 5655   8067              rescue                   Sand springs oklahoma  Coastal German Shepherd Rescue OC shared a lin...       0
# 5670   8091              rescue                  U.S.A.   FEMA Region 5  Coastal German Shepherd Rescue OC shared a lin...       0
# 2448   3514          derailment                   Palo Alto, California  Consent Order on cleanup underway at CSX derai...       1
# 2475   3549          derailment                   Palo Alto, California  Consent Order on cleanup underway at CSX derai...       1
# 220     313         annihilated                                          Cop pulls drunk driver to safety SECONDS befor...       1
# 238     338         annihilated                                          Cop pulls drunk driver to safety SECONDS befor...       1
# 218     310         annihilated                                  Boston  Cop pulls drunk driver to safety SECONDS befor...       1
# 1614   2332            collapse                                Fakefams                   Correction: Tent Collapse Story        1
# 1618   2337            collapse                                Nigeria                    Correction: Tent Collapse Story        1
# 2614   3752         destruction                                          Crackdown 3 Destruction Restricted to Multipla...       0
# 2630   3773         destruction                                          Crackdown 3 Destruction Restricted to Multipla...       0
# 2634   3777         destruction                                          Crackdown 3 Destruction Restricted to Multipla...       0
# 3947   5612            flooding                                 Vietnam  Cuban leader extends sympathy to Vietnam over ...       1
# 3960   5628            flooding                                 Vietnam  Cuban leader extends sympathy to Vietnam over ...       1
# 3528   5043          eyewitness                                          DK Eyewitness Travel Guide: Denmark: travel gu...       0
# 3529   5044          eyewitness                                          DK Eyewitness Travel Guide: Denmark: travel gu...       0
# 3535   5055          eyewitness                                          DK Eyewitness Travel Guide: Denmark: travel gu...       0
# 2668   3830            detonate                   Bronx NYC / M-City NY           Detonate (feat. M.O.P.) by Apollo Brown        0
# 2653   3810            detonate                Kln, Nordrhein-Westfalen           Detonate (feat. M.O.P.) by Apollo Brown        1
# 2704   3879          detonation                                New York  Detonation fashionable mountaineering electron...       1
# 2707   3889          detonation                                New York  Detonation fashionable mountaineering electron...       0
# 2710   3894          detonation                                New York  Detonation fashionable mountaineering electron...       0
# 7078  10139            upheaval                              London, UK  Diageo's CEO stresses that a board revolt at U...       0
# 7088  10151            upheaval                              London, UK  Diageo's CEO stresses that a board revolt at U...       0
# 3258   4680            engulfed                                          Do you feel engulfed with low self-image? Take...       0
# 3249   4670            engulfed                                Coventry  Do you feel engulfed with low self-image? Take...       0
# 3270   4695            engulfed                                Coventry  Do you feel engulfed with low self-image? Take...       0
# 6085   8692             sinking                       Cypress, CA 90630  Do you feel like you are sinking in low self-i...       0
# 6108   8721             sinking                               Liverpool  Do you feel like you are sinking in low self-i...       1
# 6087   8694             sinking                                          Do you feel like you are sinking in unhappines...       0
# 6125   8741             sinking                                Coventry  Do you feel like you are sinking in unhappines...       0
# 6118   8734             sinking                  Duval, WV 25573, USA ?  Do you feel like you are sinking in unhappines...       0
# 1542   2229  chemical_emergency                     Seattle, Washington  Downtown Emergency Service Center is hiring!  ...       0
# 1551   2240  chemical_emergency                     Seattle, Washington  Downtown Emergency Service Center is hiring!  ...       0
# 7123  10204       violent_storm                                Barbados  Dramatic Video Shows Plane Landing During Viol...       1
# 7113  10192       violent_storm                   T: 1.50225,103.742992  Dramatic Video Shows Plane Landing During Viol...       1
# 1373   1980          bush_fires                     Trinidad and Tobago    Drought fuels bush fires in Jamaica -   -   RE        1
# 1384   1995          bush_fires          Wolmers Trust School for Boys     Drought fuels bush fires in Jamaica -   -   RE        1
# 5192   7413         obliterated                                          Drunk Meals 101: What To Cook When You're Tota...       0
# 5201   7426         obliterated            1313 W.Patrick St, Frederick  Drunk Meals 101: What To Cook When You're Tota...       0
# 5194   7415         obliterated                              Reading MA  Drunk Meals 101: What To Cook When You're Tota...       1
# 5208   7438         obliterated                      Winnipeg, Manitoba  Drunk Meals 101: What To Cook When You're Tota...       0
# 2850   4096           displaced             Na:tinixw / Hoopa, Berkeley  Elem Pomo helping the displaced from the Rocky...       1
# 3374   4832          evacuation             Na:tinixw / Hoopa, Berkeley  Elem Pomo helping the displaced from the Rocky...       1
# 1545   2233  chemical_emergency                            Evanston, IL  Emergency units simulate a chemical explosion ...       1
# 1549   2238  chemical_emergency                            Evanston, IL  Emergency units simulate a chemical explosion ...       1
# 4603   6546              injury                                          Enter the world of extreme diving  9 stories u...       0
# ...
# 259     370        annihilation                            Coolidge, AZ  U.S National Park Services Tonto National Fore...       0
# 266     384        annihilation                       Tacoma,Washington  U.S National Park Services Tonto National Fore...       0
# 5652   8064              rescue                        Toronto, Ontario  UD: Rescue (Structural Collapse) - Scott Road ...       1
# 5665   8084              rescue                        Toronto, Ontario  UD: Rescue (Structural Collapse) - Scott Road ...       1
# 599     867           bioterror                     Arkansas, Jonesboro  USATODAY: On today's   lab faced secret sancti...       1
# 607     876           bioterror                          Espoo, Finland  USATODAY: On today's   lab faced secret sancti...       1
# 3046   4373          earthquake                             Hawaii, USA  USGS reports a M1.94  5km S of Volcano Hawaii ...       1
# 7135  10220             volcano                             Hawaii, USA  USGS reports a M1.94  5km S of Volcano Hawaii ...       1
# 4556   6477             injured                                          Udhampur terror attack: Militants attack polic...       1
# 4561   6484             injured                                   India  Udhampur terror attack: Militants attack polic...       1
# 4547   6464             injured                                  Mumbai  Udhampur terror attack: Militants attack polic...       1
# 5721   8164            rescuers                                          VIDEO: 'We're picking up bodies from water': R...       1
# 5706   8142            rescuers                                 Nigeria  VIDEO: 'We're picking up bodies from water': R...       1
# 5718   8161            rescuers                                          VIDEO: 'We're picking up bodies from water': R...       1
# 5725   8170            rescuers                ?????????????, Thailand   VIDEO: 'We're picking up bodies from water': R...       1
# 5708   8144            rescuers                            Kuala Lumpur  VIDEO: 'We're picking up bodies from water': R...       1
# 5719   8162            rescuers                                  London  VIDEO: 'We're picking up bodies from water': R...       1
# 5709   8146            rescuers                                Surabaya  VIDEO: 'We're picking up bodies from water': R...       1
# 5730   8177            rescuers            USA - Canada - Europe - Asia  VIDEO: 'We're picking up bodies from water': R...       1
# 5707   8143            rescuers                              Westerland  VIDEO: 'We're picking up bodies from water': R...       1
# 5731   8180            rescuers                               worldwide  VIDEO: 'We're picking up bodies from water': R...       1
# 5716   8158            rescuers                                          VIDEO: 'We're picking up bodies from water': R...       1
# 5720   8163            rescuers                                          VIDEO: 'We're picking up bodies from water': R...       1
# 5723   8168            rescuers                                          VIDEO: 'We're picking up bodies from water': R...       1
# 5734   8183            rescuers                                          VIDEO: 'We're picking up bodies from water': R...       1
# 1902   2733             crushed                    Sunny South florida   WRAPUP 2-U.S. cable TV companies' shares crush...       0
# 1895   2726             crushed                                 online   WRAPUP 2-U.S. cable TV companies' shares crush...       0
# 377     542                army                                          WWI WWII JAPANESE ARMY NAVY MILITARY JAPAN LEA...       0
# 369     528                army                                New York  WWI WWII JAPANESE ARMY NAVY MILITARY JAPAN LEA...       0
# 376     540                army                                New York  WWI WWII JAPANESE ARMY NAVY MILITARY JAPAN LEA...       0
# 7245  10375             weapons                         Rocky Mountains  WWII Memories Plus Lessons of Hiroshima We Sti...       1
# 7239  10367             weapons                                    West  WWII Memories Plus Lessons of Hiroshima We Sti...       1
# 3219   4619  emergency_services                         Los Angeles, CA  Want to work in  CA? View our latest opening: ...       0
# 3231   4637  emergency_services                         Los Angeles, CA  Want to work in  CA? View our latest opening: ...       0
# 1172   1689     bridge_collapse                          Mumbai , India  Warne shocked over Australia's epic collapse a...       1
# 1623   2346            collapse                          Mumbai , India  Warne shocked over Australia's epic collapse a...       1
# 5163   7362          obliterate                                     EIC  Watch Sarah Palin OBLITERATE Planned Parenthoo...       1
# 5177   7386          obliterate                                     EIC  Watch Sarah Palin OBLITERATE Planned Parenthoo...       0
# 5180   7392          obliterate                                   Texas  Watch Sarah Palin OBLITERATE Planned Parenthoo...       0
# 5877   8394           sandstorm                                          Watch This Airport Get Swallowed Up By A Sands...       1
# 5879   8397           sandstorm                                          Watch This Airport Get Swallowed Up By A Sands...       1
# 5901   8429           sandstorm                                          Watch This Airport Get Swallowed Up By A Sands...       1
# 5883   8402           sandstorm                                      US  Watch This Airport Get Swallowed Up By A Sands...       1
# 5876   8393           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5881   8400           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5884   8404           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5885   8405           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5889   8410           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5890   8411           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5891   8412           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5895   8418           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5896   8419           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5897   8422           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5898   8423           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5900   8428           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5903   8431           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5904   8432           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5905   8433           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5907   8435           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5911   8441           sandstorm                                     USA  Watch This Airport Get Swallowed Up By A Sands...       1
# 5888   8409           sandstorm                           United States  Watch This Airport Get Swallowed Up By A Sands...       1
# 5894   8416           sandstorm                           United States  Watch This Airport Get Swallowed Up By A Sands...       1
# 5882   8401           sandstorm                               hkXfYMhEx  Watch This Airport Get Swallowed Up By A Sands...       1
# 5055   7204    natural_disaster                                          What Natural Disaster Are You When You Get Ang...       0
# 5079   7242    natural_disaster                    Leitchfield Kentucky  What Natural Disaster Are You When You Get Ang...       0
# 3985   5662              floods                                          Who is bringing the tornadoes and floods. Who ...       1
# 4013   5699              floods                                          Who is bringing the tornadoes and floods. Who ...       0
# 4019   5710              floods                                          Who is bringing the tornadoes and floods. Who ...       0
# 2250   3221             deluged                                  London  Why are you deluged with low self-image? Take ...       1
# 2253   3227             deluged                              Manchester  Why are you deluged with low self-image? Take ...       0
# 3265   4690            engulfed                       Kenosha, WI 53143  Why are you engulfed by low self-image? Take t...       0
# 3253   4674            engulfed                               Newcastle  Why are you engulfed by low self-image? Take t...       0
# 5229   7475        obliteration                           DC Metro area  Why did God order obliteration of ancient Cana...       0
# 5224   7465        obliteration                  New Orleans ,Louisiana  Why did God order obliteration of ancient Cana...       0
# 5222   7461        obliteration                           kissimmee,fl.  Why did God order obliteration of ancient Cana...       0
# 5238   7490        obliteration                                          Why did God order obliteration of ancient Cana...       0
# 5216   7452        obliteration          Born in Baltimore Living in PA  Why did God order obliteration of ancient Cana...       0
# 248     353        annihilation                         Subconscious LA  World Annihilation vs Self Transformation  Ali...       0
# 269     390        annihilation                         Subconscious LA  World Annihilation vs Self Transformation  Ali...       1
# 5335   7614         pandemonium                                          World Class Tgirl Ass 02 - Scene 4 - Pandemonium        0
# 5338   7619         pandemonium                                          World Class Tgirl Ass 02 - Scene 4 - Pandemonium        0
# 4762   6775           lightning                                          World War II book LIGHTNING JOE An Autobiograp...       0
# 4770   6788           lightning                                          World War II book LIGHTNING JOE An Autobiograp...       1
# 7537  10776            wreckage                                   India  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7533  10771            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7521  10754            wreckage                                  Punjab  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7507  10737            wreckage                                          Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7509  10741            wreckage                                          Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7516  10749            wreckage                                          Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7524  10760            wreckage                                          Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7538  10777            wreckage                                          Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7526  10764            wreckage                    Dublin City, Ireland  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7539  10779            wreckage                             Maharashtra  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7505  10735            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7511  10744            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7519  10752            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7520  10753            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7528  10766            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7534  10772            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7536  10775            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7540  10780            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7543  10784            wreckage                                  Mumbai  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7517  10750            wreckage                     Mumbai, Maharashtra  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7541  10782            wreckage                         New Delhi,India  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7512  10745            wreckage                                  khanna  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 7529  10767            wreckage                                      uk  Wreckage 'Conclusively Confirmed' as From MH37...       1
# 2736   3933          devastated                                          abcnews - Obama Declares Disaster for Typhoon-...       1
# 7026  10071             typhoon                                          abcnews - Obama Declares Disaster for Typhoon-...       1
# 4623   6571              injury                                          incident with injury:I-495  inner loop Exit 31...       1
# 4631   6582              injury                                          incident with injury:I-495  inner loop Exit 31...       1
# 1221   1760   buildings_burning                                  dallas  like for the music video I want some real acti...       1
# 1349   1950   burning_buildings                                  dallas  like for the music video I want some real acti...       0
# 963    1393            body_bag                                          new summer long thin body bag hip A word skirt...       0
# 970    1405            body_bag                                          new summer long thin body bag hip A word skirt...       0
# 3449   4931            exploded                                          that exploded & brought about the beginning of...       0
# 3461   4952            exploded                                          that exploded & brought about the beginning of...       0
# 6094   8702             sinking                                          that horrible sinking feeling when youve been ...       0
# 6103   8714             sinking                                          that horrible sinking feeling when youve been ...       0
# 6091   8698             sinking                Every Where in the World  that horrible sinking feeling when youve been ...       1
# 6123   8739             sinking                                      MA  that horrible sinking feeling when youve been ...       1
# 5620   8018            refugees                                          wowo--=== 12000 Nigerian refugees repatriated ...       1
# 5641   8044            refugees                                          wowo--=== 12000 Nigerian refugees repatriated ...       0

# %% [markdown]
# ## Dealing with the duplicates
# The duplicated data may present problems during the model training. These items will be more heavily weighted in the cost function. Moreover, several of the duplicates have different target values. It's important to treat these special cases. Here are several ways to deal with them:
#
# - Remove all duplicates from the set
# - Select only the first occurance of each duplicate
# - For contradictory target values, select the majority case
#
# For this analysis, let's select the first occurance:

# %%
train_duplicates = train.duplicated(subset=['text'],keep='first')
train = train[~train_duplicates]
assert 0 == np.sum(train.duplicated(subset=['text']))

# %% [markdown]
# ## Locations and keywords as features
# While the train and test sets have 422 locations common among them, they also have 4095 locations that are not in common. Such locations are unlikely to help a model generalize. For this reason, we may consider removing uncommon locations as a feature from the model. We can do this by one-hot encoding common locations while reserving an 'unknown' state for the uncommon locations.
#
# The keywords form a set that is common among both train and test sets. It makes sense to include these as one-hot encoded features. Let's identify and save the common keywords and locations.

# %%
keywords = set(train.keyword).intersection(set(test.keyword))
print('Number of keywords',len(keywords))

locations = set(train.location).intersection(set(test.location))

with open('../data/keywords.txt','w') as file:
    for kw in sorted(keywords):
        file.write(kw + '\n')

# from codecs import encode   
import html

with open('../data/tweets.txt','w') as file:
    for tweet in train.text:
        #file.write((str(tweet.encode('ascii', 'ignore'),'utf8') + '\n'))
        text = html.unescape(tweet)
        text = str(text.encode('ascii','ignore'),'utf8') + '\n'
        file.write(text)
# Out:
# Number of keywords 222

# %%
train.to_csv('../data/train_cleaned.csv')
test.to_csv('../data/test_cleaned.csv')

# %%
s = 'Twelve feared killed in Pakistani air ambulance helicopter crash '
for tweet in train[train['text'].str.contains(s)]['text']:
    print(tweet.split())
# Out:
# ['Twelve', 'feared', 'killed', 'in', 'Pakistani', 'air', 'ambulance', 'helicopter', 'crash']
# ['Twelve', 'feared', 'killed', 'in', 'Pakistani', 'air', 'ambulance', 'helicopter', 'crash', '-', 'Reuters']
# ['Twelve', 'feared', 'killed', 'in', 'Pakistani', 'air', 'ambulance', 'helicopter', 'crash']
# ['Twelve', 'feared', 'killed', 'in', 'Pakistani', 'air', 'ambulance', 'helicopter', 'crash']
# ['Twelve', 'feared', 'killed', 'in', 'Pakistani', 'air', 'ambulance', 'helicopter', 'crash']

# %%
pakistan_duplicates = train['text'].str.contains(s)
pak_dups = train[pakistan_duplicates].copy()
for index, row in pak_dups.iterrows():
    print(row.id, row.keyword, row.location, row.text,)
# Out:
# 247 ambulance Jackson  Twelve feared killed in Pakistani air ambulance helicopter crash
# 249 ambulance  Twelve feared killed in Pakistani air ambulance helicopter crash - Reuters
# 253 ambulance  Twelve feared killed in Pakistani air ambulance helicopter crash
# 261 ambulance   Twelve feared killed in Pakistani air ambulance helicopter crash
# 287 ambulance USA Twelve feared killed in Pakistani air ambulance helicopter crash

# %%
#pak_dups = pak_dups.drop(['location'],inplace=True,axis=1)
pak_dups['text'] = pak_dups['text'].str.split()
pak_dups
# Out:
#       id    keyword location                                               text  target
# 172  247  ambulance  Jackson  [Twelve, feared, killed, in, Pakistani, air, a...       1
# 174  249  ambulance           [Twelve, feared, killed, in, Pakistani, air, a...       1
# 177  253  ambulance           [Twelve, feared, killed, in, Pakistani, air, a...       1
# 182  261  ambulance           [Twelve, feared, killed, in, Pakistani, air, a...       1
# 203  287  ambulance      USA  [Twelve, feared, killed, in, Pakistani, air, a...       1

# %% [markdown]
# Looking offline at the saved files, it's apparent that there are still lots of duplicates. Some of these have different locations, others have minor differences in the text such as including different hashtags and punctuation. Further cleaning would be ideal, but it's not clear how deep it should go.
#
# Let's put together a function to detect duplicates. The challenge is that the duplicates are not all exactly identical (the pandas `.duplicated()` method does not detect them) but they appear as duplicates. Some have different keywords. These can be eliminated by

# %%
import dill
dill.dump_session('../session/DataWrangling_EDA.db')

# %%
import dill
dill.load_session('../session/DataWrangling_EDA.db')

# %%
pak_dups
# Out:
#       id    keyword location                                               text  target
# 172  247  ambulance  Jackson  [Twelve, feared, killed, in, Pakistani, air, a...       1
# 174  249  ambulance           [Twelve, feared, killed, in, Pakistani, air, a...       1
# 177  253  ambulance           [Twelve, feared, killed, in, Pakistani, air, a...       1
# 182  261  ambulance           [Twelve, feared, killed, in, Pakistani, air, a...       1
# 203  287  ambulance      USA  [Twelve, feared, killed, in, Pakistani, air, a...       1

# %%
pak_dups.sample(2)
# Out:
#       id    keyword location                                               text  target
# 177  253  ambulance           [Twelve, feared, killed, in, Pakistani, air, a...       1
# 172  247  ambulance  Jackson  [Twelve, feared, killed, in, Pakistani, air, a...       1
