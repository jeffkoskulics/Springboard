# %% [markdown]
# # Exploratory Data Analysis (EDA)
# In this notebook, we explore the data. The tasks covered include:
# 1. Investigate every feature using histograms, bi-plots and other visual and numerical means.
# 2. Compute Pearson correlation coefficients and other statistical methods to identify statistical relationship strengths.
# 3. Make data-supported decisions on when to select specific features

# %%
import pandas as pd

wine = pd.read_csv('../data/all_wines.csv',index_col = False)

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  type_white
# 0      8.8        6           1
# 1      9.5        6           1
# 2     10.1        6           1
# 3      9.9        6           1
# 4      9.9        6           1

# %%
# Helper function for an array of boxplots

import matplotlib.pyplot as plt

def boxplots(df):
    num_columns_to_plot = len(df.columns)
    num_columns = 4
    num_rows = -(-num_columns_to_plot // 4)
    col_names = df.columns
    plt.figure(figsize=(24,12))
    for i, col in enumerate(col_names):
        plt.subplot(num_rows,num_columns//3,i+1)
        df.boxplot(column = col,fontsize=18)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Let's review the range of each variable using boxplots:

# %%
boxplots(wine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f21f516b0135> in <module>
# ----> 1 boxplots(wine)
#
# <ipython-input-6-60840f3a9dc1> in boxplots(df)
#       8     plt.figure(figsize=(24,12))
#       9     for i, col in enumerate(col_names):
# ---> 10         plt.subplot(3,num_columns//3,i+1)
#      11         df.boxplot(column = col,fontsize=18)
#      12     plt.tight_layout()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      57                 if num < 1 or num > rows*cols:
#      58                     raise ValueError(
# ---> 59                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      60                 self._subplotspec = GridSpec(
#      61                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 12, not 13
